# %% [markdown]
# # TimeSeries Forecasting @Datalift Conference Workshop in Berlin - Elia Group

# %% [markdown]
# created by the Center of Excellence AI Elia Group (Christian Merz, Thomas Craessaerts, Raphael Croegaert, Rachel Berryman)
#
# Link to the app: https://share.streamlit.io/chris-elia/ts-forecast/main/main.py
#
#
# Contact: Artificialintelligence@eliagroup.eu

# %% [markdown]
# ### Agenda ###
# 0. (**Set-up environment**)
#
# 1. **Exploring the data**  🔍
#  1.1. Elia Open Data (Total Load, PV and Wind production)
#  1.2 Rebase API Weather Forecast
#  1.3 Quick Visualization of the Data
#
# 1. **Time Series forecasting with Prophet** 📈
#  2.1 Univariate Forecasting
#  2.2 Multivariate Forecasting
#
# 3. **Putting everything together in a Web App with Streamlit** 🚀
#    3.1   Layout & Functionalities
#    3.2 Streamlit Cloud Deployment

# %% [markdown]
# <img src="./data/Architecture_Layout.png" alt="Drawing" style="width: 1000px;"/>

# %% [markdown]
# ### 0. Set-up dependencies
#
# To run this notebook and the forecasting app, you need certain dependencies.
# To make it as simple as possible, everything is wrapped up in a conda environment file.
# Therefore run the two following commands in command line:
# - **conda env create -f environment.yml**
# - **conda activate conda_timeseries_forecaster**
#
# The first one will install the python version with the required packages. The second command will activate the conda environment.
#
#
#
# **Python Version**
# - Python: 3.8.13
#
# **Required packages**
# - pip install streamlit
# - pip install pystan==2.19.1.1
# - conda install prophet

# %% [markdown]
# ###     1. Exploring the data from the Elia OpenData Platform 🔍

# %% [markdown]
# https://opendata.elia.be/pages/home/
#
#
# https://api.rebase.energy/weather/docs/v2/
#
# https://realto.io/api-marketplace/

# %% [markdown]
# #### 1.1. Elia Open DataAPI

# %% [markdown]
# **Total Load:** https://opendata.elia.be/explore/dataset/ods003/api/
#
# **PV production:** https://opendata.elia.be/explore/dataset/ods032/api
#
# **Wind production:** https://opendata.elia.be/explore/dataset/ods031/api

# %%
#### Import of the neccessary libraries ###
import requests
import pandas as pd

def get_open_data_elia_df(dataset, start_date, end_date):
    """Gets and returns the selected dataset from the Elia Open Data Platform within a given time range

    Parameters
    ----------
    dataset: str
        the selected dataset identifier from the Elia Open Data Platform
    start_date: str
        The start date of the selected dataset, Format: "YYYY-MM-DD"
    end_date: str
        The end date of the selected dataset, Format: "YYYY-MM-DD"    
    

    Returns
    -------
    pd.Dataframe
        a dataframe containing the selected data
    
    """

    url = f"https://opendata.elia.be/api/v2/catalog/datasets/{dataset}/exports/"
    json_string = f"json?where=datetime in [date'{start_date}' .. date'{end_date}']"
    
    response = requests.get(url = url + json_string)

    # calling the Elia Open Data API
    df = pd.DataFrame(response.json())
    
    df.sort_values(by = "datetime", inplace = True)
    df.reset_index(inplace = True, drop =  True)    
    df["datetime"] = pd.to_datetime(df["datetime"]).dt.tz_localize(None)

    return df

# %% [markdown]
# **Test the Open Data Function**

# %%
dataset = "ods003"
start_date = "2022-06-24"
end_date = "2022-06-22"
df_open_data = get_open_data_elia_df(dataset, start_date , end_date )
df_open_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       2 start_date = "2022-06-24"
#       3 end_date = "2022-06-22"
# ----> 4 df_open_data = get_open_data_elia_df(dataset, start_date , end_date )
#       5 df_open_data.head()
#
# Input In [1], in get_open_data_elia_df(dataset, start_date, end_date)
#      30 # calling the Elia Open Data API
#      31 df = pd.DataFrame(response.json())
# ---> 33 df.sort_values(by = "datetime", inplace = True)
#      34 df.reset_index(inplace = True, drop =  True)
#      35 df["datetime"] = pd.to_datetime(df["datetime"]).dt.tz_localize(None)
#
# File ~/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/pandas/core/frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# -> 6313     k = self._get_label_or_level_values(by, axis=axis)
#    6315     # need to rewrap column in Series to apply key function
#    6316     if key is not None:
#    6317         # error: Incompatible types in assignment (expression has type
#    6318         # "Series", variable has type "ndarray")
#
# File ~/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/pandas/core/generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'datetime'

# %% [markdown]
# #### 1.2 Rebase Weather Forecast

# %%
def get_weather_forecast(start_date, end_date, latitude, longitude):
    
    secret = "W-cRKEYdwzL6mdWCYO2_UZSOWI1MxET07dquSY9Fck4"
    """
    Gets and returns the weather forecast from rebase within a given time range

    Parameters
    ----------
    start_date: str
        The start date of the selected dataset, Format: "YYYY-MM-DD"
    end_date: str
        The end date of the selected dataset, Format: "YYYY-MM-DD"
    latitude: str
        The latitude value (Geo location) of the city for the weather forecast
    longitude: str
        The longitude value (Geo location) of the city for the weather forecast

    Returns
    -------
    pd.Dataframe
        a dataframe containing the selected data
    
    """

    start_date = pd.to_datetime(start_date)
    end_date = pd.to_datetime(end_date)

    # Authentication
    url = "https://api.rebase.energy/weather/v2/query"
    headers = {"Authorization": secret } ## to be changed to st.secrets["REBASE_KEY"]
    params = {
        'model': 'FMI_HIRLAM',
        'start-date': start_date,
        'end-date': end_date,
        'reference-time-freq': '24H',
        'forecast-horizon': 'latest',
        'latitude': latitude,
        'longitude': longitude,
        'variables': 'Temperature, WindSpeed, SolarDownwardRadiation'
    }
    response = requests.get(url, headers=headers, params=params)

    # Clean data
    df = pd.DataFrame(response.json())
    df = df.drop('ref_datetime', axis=1)
    df["valid_datetime"] = pd.to_datetime(df["valid_datetime"]).dt.tz_localize(None)

    df = df.rename(columns={'valid_datetime': 'datetime'})
    df = df.drop_duplicates(keep='last')
    df = df.fillna(0)

    return df

# %% [markdown]
# **Test Weather Forecast Rebase**

# %%
start_date = "2022-06-22"
end_date = "2022-06-24"
latitude = "50.85045"
longitude = "4.34878"
df_weather = get_weather_forecast(start_date, end_date, latitude, longitude)

df_weather.head()
# Out:
#              datetime  SolarDownwardRadiation  Temperature  WindSpeed
# 0 2022-06-22 00:00:00                    0.00        12.33       1.67
# 1 2022-06-22 01:00:00                    0.00        12.32       2.12
# 2 2022-06-22 02:00:00                    0.00        11.63       2.02
# 3 2022-06-22 03:00:00                    0.00        11.01       2.11
# 4 2022-06-22 04:00:00                    4.81        10.62       1.95

# %% [markdown]
# ### 1.3 Quick Visualization of the Data

# %%
df_grid_load = get_open_data_elia_df("ods003", "2022-06-22", "2022-06-24")
df_grid_load = df_grid_load.loc[:,["datetime", "eliagridload"]]
#df_ts.set_index("datetime", inplace=True)
df_grid_load.plot(
    x = df_grid_load.columns[0],
    y = df_grid_load.columns[1],
    title = "Total Load in the Elia Grid",
    ylabel = "MW",
    xlabel = "Time"
)
# Out:
# <AxesSubplot:title={'center':'Total Load in the Elia Grid'}, xlabel='Time', ylabel='MW'>

# %%
df_weather = get_weather_forecast("2022-06-22", "2022-06-24", latitude = "50.85045", longitude = "4.34878")
#df_weather = df_weather.loc[:,["datetime", "eliagridload"]]
#df_ts.set_index("datetime", inplace=True)
df_weather.plot(
    x = df_weather.columns[0],
    y = [df_weather.columns[1],df_weather.columns[2],df_weather.columns[3]],
    title = "Total Load in the Elia Grid",
    xlabel = "Time",
    subplots = True
)
# Out:
# array([<AxesSubplot:xlabel='Time'>, <AxesSubplot:xlabel='Time'>,
#        <AxesSubplot:xlabel='Time'>], dtype=object)

# %% [markdown]
# **What we have achived so far**
#
# <img src="./data/Architecture_Layout Step 2.png" alt="Drawing" style="width: 700px;"/>

# %% [markdown]
# ## 2. Timeseries Forecasting with Prophet (Facebook) 📈

# %% [markdown]
# The Prophet library is an open-source library designed for making forecasts for univariate time series datasets.
# It is a procedure for forecasting time series data based on an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects. It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.

# %% [markdown]
# **Documentation:** https://facebook.github.io/prophet/docs/quick_start.html

# %% [markdown]
# #### Univariate Forecasting
#
# Tasks for you to do:
#
# 1. Get familiar with the Prophet API and make a simple prediction -> check out the documentation
# 2. Wrap everything together in a function

# %%
# 1. Get familiar with the Prophet API and make a simple prediction -> check out the documentation

import pandas 
from prophet import Prophet

# read in the test_data_grid.csv file as a dataframe 
df = pd.read_csv("data/test_data_grid.csv", index_col=0)

# have a quick look at the data
df.head()

# rename the columns of the dataframe to the Prophet convention
df = df.rename(columns={"datetime": "ds", "eliagridload": "y"})

# creating a Prophet object
    ## optional parameters can be set here like:
    ## seasonality, changepoints, uncertainty intervals etc. see help(Prophet)
    ## e.g. weekly_seasonality = True
m = Prophet()

# Fit the data to the Prophet object
    ## fit() methods expects a dataframe with the column heads ds and y
m.fit(df)

# Create the future dataframe and set the frequency to Hours
     ## periods: Int number of periods to forecast forward.
     ## freq: Any valid frequency for pd.date_range, such as 'M (month), 'D'(day) or 'H' (hour).
future = m.make_future_dataframe(periods=22, freq='H')


# Make the prediction
     ## expects a dataframe with dates for predictions 
     ## (created above with make_future_dataframe)
forecast = m.predict(future)
    
# Create some plots of the forecast
    ## forecast plot
m.plot(forecast)

    ## components plot
fig2 = m.plot_components(forecast)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Initial log joint probability = -5.06779
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       774.836     0.0023638       75.8675       0.227           1      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      153       775.076   0.000143435       76.4248   2.013e-06       0.001      240  LS failed, Hessian reset
#      199        775.09   2.15691e-05         57.67      0.8192      0.8192      296
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      233        775.68   0.000572999       77.0939    6.13e-06       0.001      368  LS failed, Hessian reset
#      299       776.063   6.48627e-08       70.8874      0.3415      0.3415      460
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      304       776.063   6.49115e-09       72.9091      0.1084      0.1084      467
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
# 2. Wrap everything together in a function

from prophet import Prophet
import pandas as pd

def run_forecast_univariate(df, periods):
    """
    returns the univariate prophet forecast + two graphic objects (forecast & composite)

    Parameters
    ----------
    df: DataFrame
        a dataframe that includes the historical data
    periods: int
        the time steps to forecast

    Returns
    -------
    forecast
        a dataframe containing the foecast data
    fig_forecast
        a figure forecast to plot
    fig_components
        a figure components to plot

    """


    df = pd.read_csv("data/test_data_grid.csv", index_col=0)

    # have a quick look at the data
    df.head()

    # rename the columns of the dataframe to the Prophet convention
    df = df.rename(columns={"datetime": "ds", "eliagridload": "y"})

    # creating a Prophet object
    ## optional parameters can be set here like:
    ## seasonality, changepoints, uncertainty intervals etc. see help(Prophet)
    ## e.g. weekly_seasonality = True
    m = Prophet()

    # Fit the data to the Prophet object
    ## fit() methods expects a dataframe with the column heads ds and y
    m.fit(df)

    # Create the future dataframe and set the frequency to Hours
    ## periods: Int number of periods to forecast forward.
    ## freq: Any valid frequency for pd.date_range, such as 'M (month), 'D'(day) or 'H' (hour).
    future = m.make_future_dataframe(periods=22, freq='H')

    # Make the prediction
    ## expects a dataframe with dates for predictions
    ## (created above with make_future_dataframe)
    forecast = m.predict(future)

    # Create some plots of the forecast
    ## forecast plot
    fig_forecast = m.plot(forecast)

    ## components plot
    fig_comp = m.plot_components(forecast)

    return forecast, fig_forecast, fig_comp

# %% [markdown]
# **Test Univariate Forecast**

# %%
df_grid_load = get_open_data_elia_df("ods003", "2022-06-02", "2022-06-24")
df_grid_load = df_grid_load.loc[:,["datetime", "eliagridload"]]
forecast, fig_forecast, fig_comp = run_forecast_univariate(df_grid_load, 100)

print(fig_forecast)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Initial log joint probability = -5.06779
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       774.836     0.0023638       75.8675       0.227           1      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      153       775.076   0.000143435       76.4248   2.013e-06       0.001      240  LS failed, Hessian reset
#      199        775.09   2.15691e-05         57.67      0.8192      0.8192      296
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      233        775.68   0.000572999       77.0939    6.13e-06       0.001      368  LS failed, Hessian reset
#      299       776.063   6.48627e-08       70.8874      0.3415      0.3415      460
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      304       776.063   6.49115e-09       72.9091      0.1084      0.1084      467
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Figure(720x432)
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %% [markdown]
# **What we have achived so far**
#
# <img src="./data/Architecture_Layout Step 3_5.png" alt="Drawing" style="width: 700px;"/>

# %% [markdown]
# #### Multivariate Forecasting

# %% [markdown]
# For multivariate forecasting we need additional features.
# In this example we **include the weather forecast** (solar radiation, wind speed and temperature) **as additional features**.
# Therefore we need to combine the historical data with the weather data. This is done with the function *prepare_data_for_mv_fc*

# %%
from prophet import Prophet
from prophet.utilities import regressor_coefficients
from datetime import timedelta
import pandas as pd

from prophet.utilities import regressor_coefficients
# from modules.fetch_data import get_weather_forecast, get_open_data_elia_df


def prepare_data_for_mv_fc(dataset, start_date, end_date, solar, wind, temp, lat,long):
    """
    Prepares and merges weather data with historical data for multivariate forecast with prophet

    Parameters
    ----------
    dataset: str
        the selected dataset identifier from the Elia Open Data Platform
    start_date: str
        The start date of the selected dataset, Format: "YYYY-MM-DD"
    end_date: str
        The end date of the selected dataset, Format: "YYYY-MM-DD"    
    solar: bool
        if True, solar data will be added as additional regressor
    wind: bool
        if True, wind data will be added as additional regressor
    temp: bool
        if True, temp data will be added as additional regressor
    lat: str
        The latitude value (Geo location) of the city for the weather forecast
    long: str
        The longitude value (Geo location) of the city for the weather forecast


    Returns
    -------
    pd.Dataframe
        a dataframe containing the merged historical and weather data
    

    """
    # catch open data
    if (dataset == "ods003"): # total load
        df = get_open_data_elia_df(dataset,start_date, end_date) 
        df.set_index(df["datetime"], inplace = True)
        df = df.resample("H").mean()
        df.reset_index(inplace = True)
        
    else:  # for solar & wind 
        df = get_open_data_elia_df(dataset,start_date, end_date) 
        df = df.groupby("datetime").sum()
        df = df.resample("H").mean()
        df.reset_index(inplace = True)
        df = df.loc[:,["datetime", "mostrecentforecast"]]
        df["datetime"] = pd.to_datetime(df["datetime"]).dt.tz_localize(None)

    # specifying variables
    start_date= df["datetime"].iloc[0]
    end_date = df["datetime"].iloc[-1]
    latitude = lat
    longitude = long

    # get weather forecast
    df_weather = get_weather_forecast(start_date, end_date, latitude, longitude)
    columns = []
    if solar:
        columns.append("SolarDownwardRadiation")
    if wind:  
        columns.append("WindSpeed")
    if temp:
        columns.append("Temperature")

    columns.append("datetime")
    df_weather = df_weather.loc[:,columns]    
    df_merged = df.merge(df_weather, on = "datetime")

    df_merged.rename(columns = {df.columns[0]: "ds", df.columns[1]:"y"}, inplace = True)

    return df_merged

# %% [markdown]
# **Task:**
#
# Add two lines of code to the *run_forecast_multivariate* function to add the additional columns/features to the prophet model.

# %%
secret = "W-cRKEYdwzL6mdWCYO2_UZSOWI1MxET07dquSY9Fck4"
def run_forecast_multivariate(df_merged, lat, long, forecast_horizon):

    """
    returns the multivariate prophet forecast + two graphic objects (forecast & components) + regressor coeffiecnt dataframe

    Parameters
    ----------
    df_merged: DataFrame
        a dataframe that includes the historical data + 
    lat:
        latitude value of geo localization for weather forecast
    long:
        longitude value of geo localization for weather forecast
    forecast_horizon: int
        the time steps to forecast

    Returns
    -------
    forecast
        a dataframe containing the foecast data
    fig_forecast
        a figure forecast to plot
    fig_components
        a figure components to plot
    reg_coef
        a dataframe with the coefficiencts of the additional regressors

    """
    # date calculation
    end_date = df_merged["ds"].sort_values().iloc[-1] # last date of the historical data    
    start_date_forecast = end_date + timedelta(hours = 1) # first date for the forecast
    end_date_forecast = start_date_forecast + timedelta(hours = forecast_horizon) # last date for the forecast

    # get weather forecast
    weather_forecast = get_weather_forecast(start_date_forecast, end_date_forecast, lat, long)
    
    # creating Prophet Object
    m = Prophet() 
    
    # creating an addiitional regressor for each additional column that is provided
        ## create a for loop that loops through the additional columns of df_merged
        # use the .add_regressor() function to add the additional columns to the prophet model
    for col in df_merged.columns[2:]:
        m.add_regressor(col)


    # fit() methods expects a dataframe with the column heads ds and y
    # fits the prophet model to the data
    m.fit(df_merged)

    # Definition of forecast range
    ## periods: Int number of periods to forecast forward. 
    ## req: Any valid frequency for pd.date_range, such as 'D' or 'M'.
    future = m.make_future_dataframe(periods=forecast_horizon, freq = "H")
    future = future.merge(weather_forecast, left_on= "ds", right_on = "datetime")

    # Prediction
    ## expects a dataframe with dates for predictions 
    ## (created above with make_future_dataframe)
    forecast = m.predict(future)

    # plotting
    fig_forecast = m.plot(forecast)
    fig_components = m.plot_components(forecast)

    reg_coef = regressor_coefficients(m)
    
    return forecast, fig_forecast, fig_components, reg_coef

# %% [markdown]
# **Test the Multivariate Forecast Function**

# %%
lat = "50.85045"
long = "4.34878"
forecast_horizon = 100

df_merged = prepare_data_for_mv_fc("ods003", "2022-06-21", "2022-06-24", True, True, False, lat, long)
forecast, fig_forecast, fig_components, reg_coef = run_forecast_multivariate(df_merged, lat, long, forecast_horizon)

print(fig_forecast)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Initial log joint probability = -51.2233
# Iteration  1. Log joint probability =    85.4069. Improved by 136.63.
# Iteration  2. Log joint probability =    129.386. Improved by 43.9794.
# Iteration  3. Log joint probability =    181.436. Improved by 52.05.
# Iteration  4. Log joint probability =    207.534. Improved by 26.0972.
# Iteration  5. Log joint probability =    214.331. Improved by 6.79758.
# Iteration  6. Log joint probability =    214.342. Improved by 0.011207.
# Iteration  7. Log joint probability =    214.411. Improved by 0.068556.
# Iteration  8. Log joint probability =    214.453. Improved by 0.0424798.
# Iteration  9. Log joint probability =     214.58. Improved by 0.12613.
# Iteration 10. Log joint probability =    214.674. Improved by 0.0946004.
# Iteration 11. Log joint probability =    214.701. Improved by 0.0264677.
# Iteration 12. Log joint probability =    214.732. Improved by 0.0310366.
# Iteration 13. Log joint probability =    215.038. Improved by 0.306303.
# Iteration 14. Log joint probability =     215.11. Improved by 0.0725656.
# Iteration 15. Log joint probability =    215.233. Improved by 0.122621.
# Iteration 16. Log joint probability =    215.395. Improved by 0.161553.
# Iteration 17. Log joint probability =    215.439. Improved by 0.0445759.
# Iteration 18. Log joint probability =    215.872. Improved by 0.432852.
# Iteration 19. Log joint probability =    215.912. Improved by 0.0395206.
# Iteration 20. Log joint probability =    216.639. Improved by 0.727819.
# Iteration 21. Log joint probability =    216.826. Improved by 0.186512.
# Iteration 22. Log joint probability =    217.079. Improved by 0.252765.
# Iteration 23. Log joint probability =    217.194. Improved by 0.115259.
# Iteration 24. Log joint probability =    217.244. Improved by 0.0495477.
# Iteration 25. Log joint probability =      217.3. Improved by 0.0561407.
# Iteration 26. Log joint probability =    218.753. Improved by 1.45316.
# Iteration 27. Log joint probability =    218.866. Improved by 0.113137.
# Iteration 28. Log joint probability =    219.081. Improved by 0.214821.
# Iteration 29. Log joint probability =     219.25. Improved by 0.169216.
# Iteration 30. Log joint probability =    219.261. Improved by 0.0107838.
# Iteration 31. Log joint probability =    219.318. Improved by 0.0573949.
# Iteration 32. Log joint probability =    219.374. Improved by 0.0563053.
# Iteration 33. Log joint probability =    219.401. Improved by 0.0268765.
# Iteration 34. Log joint probability =     219.42. Improved by 0.0188731.
# Iteration 35. Log joint probability =     219.43. Improved by 0.0102237.
# Iteration 36. Log joint probability =    219.438. Improved by 0.00803697.
# Iteration 37. Log joint probability =    219.441. Improved by 0.00272159.
# Iteration 38. Log joint probability =    219.448. Improved by 0.00679209.
# Iteration 39. Log joint probability =    219.449. Improved by 0.000551001.
# Iteration 40. Log joint probability =     219.45. Improved by 0.0012019.
# Iteration 41. Log joint probability =     219.45. Improved by 0.000425044.
# Iteration 42. Log joint probability =    219.454. Improved by 0.0038509.
# Iteration 43. Log joint probability =    219.455. Improved by 0.000851345.
# Iteration 44. Log joint probability =    219.456. Improved by 0.0015633.
# Iteration 45. Log joint probability =    219.457. Improved by 0.000478822.
# Iteration 46. Log joint probability =    219.458. Improved by 0.00062464.
# Iteration 47. Log joint probability =    219.458. Improved by 0.000310967.
# Iteration 48. Log joint probability =    219.458. Improved by 0.000228411.
# Iteration 49. Log joint probability =    219.458. Improved by 0.000378059.
# Iteration 50. Log joint probability =    219.459. Improved by 0.00018074.
# Iteration 51. Log joint probability =    219.459. Improved by 0.00018951.
# Iteration 52. Log joint probability =    219.459. Improved by 2.74579e-05.
# Iteration 53. Log joint probability =    219.459. Improved by 1.66479e-05.
# Iteration 54. Log joint probability =    219.459. Improved by 0.000105499.
# Iteration 55. Log joint probability =    219.459. Improved by 7.16408e-05.
# Iteration 56. Log joint probability =    219.459. Improved by 3.87616e-05.
# Iteration 57. Log joint probability =    219.459. Improved by 4.50919e-05.
# Iteration 58. Log joint probability =    219.459. Improved by 2.29881e-05.
# Iteration 59. Log joint probability =    219.459. Improved by 1.26167e-05.
# Iteration 60. Log joint probability =    219.459. Improved by 1.36596e-05.
# Iteration 61. Log joint probability =    219.459. Improved by 9.21882e-06.
# Iteration 62. Log joint probability =    219.459. Improved by 7.16667e-06.
# Iteration 63. Log joint probability =    219.459. Improved by 1.77224e-06.
# Iteration 64. Log joint probability =    219.459. Improved by 5.54409e-06.
# Iteration 65. Log joint probability =    219.459. Improved by 1.18884e-06.
# Iteration 66. Log joint probability =    219.459. Improved by 5.39725e-06.
# Iteration 67. Log joint probability =    219.459. Improved by 4.56572e-06.
# Iteration 68. Log joint probability =    219.459. Improved by 1.8446e-06.
# Iteration 69. Log joint probability =    219.459. Improved by 9.01481e-07.
# Iteration 70. Log joint probability =    219.459. Improved by 3.21948e-06.
# Iteration 71. Log joint probability =    219.459. Improved by 1.42817e-06.
# Iteration 72. Log joint probability =    219.459. Improved by 1.32501e-07.
# Iteration 73. Log joint probability =    219.459. Improved by 7.93773e-07.
# Iteration 74. Log joint probability =    219.459. Improved by 6.1719e-07.
# Iteration 75. Log joint probability =    219.459. Improved by 1.71472e-06.
# Iteration 76. Log joint probability =    219.459. Improved by 4.19908e-07.
# Iteration 77. Log joint probability =    219.459. Improved by 2.74995e-07.
# Iteration 78. Log joint probability =    219.459. Improved by 8.27105e-07.
# Iteration 79. Log joint probability =    219.459. Improved by 3.24264e-07.
# Iteration 80. Log joint probability =    219.459. Improved by 3.91474e-07.
# Iteration 81. Log joint probability =    219.459. Improved by 1.3535e-07.
# Iteration 82. Log joint probability =    219.459. Improved by 1.42258e-07.
# Iteration 83. Log joint probability =    219.459. Improved by 6.02469e-08.
# Iteration 84. Log joint probability =    219.459. Improved by 6.30698e-08.
# Iteration 85. Log joint probability =    219.459. Improved by 3.49497e-08.
# Iteration 86. Log joint probability =    219.459. Improved by 4.57662e-08.
# Iteration 87. Log joint probability =    219.459. Improved by 1.68652e-08.
# Iteration 88. Log joint probability =    219.459. Improved by 2.67317e-08.
# Iteration 89. Log joint probability =    219.459. Improved by 1.36852e-08.
# Iteration 90. Log joint probability =    219.459. Improved by 6.01204e-09.
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /Users/alial-saeedi/opt/miniconda3/envs/conda_timeseries_forecaster/lib/python3.8/site-packages/prophet/forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Figure(720x432)

# %% [markdown]
# **What we have achived so far**
#
# <img src="./data/Architecture_Layout Step 3.png" alt="Drawing" style="width: 700px;"/>

# %% [markdown]
# ## Putting everything together in a Web App with Streamlit 🚀
#
# Let's move to Visual Studio Code and implement the functions and create the layout.

# %% [markdown]
# Therefore we have organised the described functions above in seperate .py files
#
# <img src="./data/Architecture_Layout Step 4.png" alt="Drawing" style="width: 700px;"/>
